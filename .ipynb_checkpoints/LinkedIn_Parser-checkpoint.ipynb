# %%
import requests
from bs4 import BeautifulSoup
import time
import random
import json
from urllib.parse import quote
import datetime

# --- Configurare ---
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
jobs_list = []
unique_job_links = set()
output_file = 'E-Commerce_jobs_germany6month_19_10.json'
autosave_interval = 300  # 5 minute

germany_cities = ["Germany"]
keywords = [
    "E-Commerce Marketing Specialist", "Online Sales Specialist", "E-Commerce Spezialist", "Sales Specialist E-Commerce",
    "Marketplace Manager assistant", "Amazon Marketplace Manager ", "E-Commerce Specialist", "Marketplace Manager",
    "Customer Service Specialist Logistik & E-Commerce", "Kaufmännischer Mitarbeiter Schwerpunkt Auftragsbearbeitung",
    "Customer Service Mitarbeiter in E-Commerce", "Werkstudent/in Customer Care E-Commerce", "E-Commerce Support Specialist",
    "Customer Service Specialist (Logistik & E-Commerce)", "Junior E-Commerce Manager", "Fachkraft Lagerlogistik Fulfillment / E-Commerce",
    "mitarbeiter/in e-commerce / e-commerce medewerker", "e-commerce manager / online shop manager", "online marketing manager", 
    "product data / katalog manager", "webshop/shop content manager", "Sachbearbeiter E Commerce", 
    "Digital Sales Spezialist / Online Sales Spezialist", "E-Commerce Marketing Spezialist"
]

def save_data_to_json(data, filename):
    with open(filename, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)

def get_user_choice():
    # ... (Funcția rămâne neschimbată)
    print("🤖 Bun venit! Alegeți perioada pentru căutarea de joburi:")
    print("="*50)
    print("1: Ultima lună (o singură căutare)")
    print("2: Ultimele 3 luni (rulează 3 căutări: pt 1, 2, și 3 luni)")
    print("3: Ultimele 6 luni (rulează 6 căutări: pt 1, 2...6 luni)")
    print("4: Perioadă personalizată (ex: ultimele 4 luni)")
    print("5: Oricând (toate joburile, o singură căutare)")
    print("="*50)
    time_options = {
        "1_month": {"label": "Ultima lună", "seconds": "r2592000"},
        "anytime": {"label": "Oricând", "seconds": ""}
    }
    filters_to_process = []
    while True:
        choice = input("Introduceți numărul opțiunii (1-5): ")
        if choice == "1":
            print("\n✅ Ați ales: Căutare pentru ultima lună.")
            filters_to_process.append(time_options["1_month"])
            break
        elif choice == "2":
            print("\n✅ Ați ales: Căutare secvențială pentru ultimele 3 luni.")
            for i in range(1, 4):
                seconds = i * 2592000
                filters_to_process.append({"label": f"Ultimele {i} luni", "seconds": f"r{seconds}"})
            break
        elif choice == "3":
            print("\n✅ Ați ales: Căutare secvențială pentru ultimele 6 luni.")
            for i in range(1, 7):
                seconds = i * 2592000
                filters_to_process.append({"label": f"Ultimele {i} luni", "seconds": f"r{seconds}"})
            break
        elif choice == "4":
            while True:
                try:
                    num_months = int(input("Introduceți numărul de luni pentru căutare (ex: 4): "))
                    if num_months > 0:
                        print(f"\n✅ Ați ales: Căutare secvențială pentru ultimele {num_months} luni.")
                        for i in range(1, num_months + 1):
                            seconds = i * 2592000
                            filters_to_process.append({"label": f"Ultimele {i} luni", "seconds": f"r{seconds}"})
                        break
                    else:
                        print("❌ Vă rugăm introduceți un număr pozitiv.")
                except ValueError:
                    print("❌ Input invalid. Vă rugăm introduceți un număr întreg.")
            break
        elif choice == "5":
            print("\n✅ Ați ales: Căutare pentru 'Oricând'.")
            filters_to_process.append(time_options["anytime"])
            break
        else:
            print("❌ Opțiune invalidă. Vă rugăm alegeți un număr între 1 și 5.")
    return filters_to_process

# ### FUNCȚIE ACTUALIZATĂ ###
def extract_job_details(job_soup):
    """Extrage detalii specifice de pe pagina individuală a unui job, fiind atent la mai multe limbi."""
    details = {
        'description': 'N/A',
        'publishedAt': 'N/A',
        'contractType': 'N/A',
        'experienceLevel': 'N/A', # Câmp nou
        'workType': 'N/A',
        'sector': 'N/A',
        'salary': 'N/A' # Câmp nou
    }

    # 1. Descriere
    desc_block = job_soup.find('div', class_='description__text')
    if desc_block:
        details['description'] = desc_block.get_text(separator='\n', strip=True)

    # 2. Data postării
    posted_time_element = job_soup.find('span', class_='posted-time-ago__text')
    if posted_time_element:
        details['publishedAt'] = posted_time_element.text.strip()
        
    # 3. Salariu (adesea într-un element separat)
    salary_element = job_soup.find('div', class_='salary-main-rail-card__salary-info')
    if not salary_element: # Încearcă un alt selector comun
         salary_element = job_soup.find('span', class_='job-details-jobs-unified-top-card__salary-insight-text')
    if salary_element:
        details['salary'] = salary_element.get_text(strip=True).replace('\n', ' ').strip()

    # 4. Criterii (Tip contract, Experiență etc.)
    criteria_list = job_soup.find('ul', class_='description__job-criteria-list')
    if criteria_list:
        criteria_items = criteria_list.find_all('li', class_='description__job-criteria-item')
        for item in criteria_items:
            header = item.find('h3', class_='description__job-criteria-subheader')
            text = item.find('span', class_='description__job-criteria-text')
            if header and text:
                header_text = header.text.strip().lower()
                text_value = text.text.strip()
                
                # Caută Nivel de experiență (engleză sau germană)
                if 'seniority level' in header_text or 'karrierestufe' in header_text:
                    details['experienceLevel'] = text_value
                # Caută Tipul de contract (engleză sau germană)
                elif 'employment type' in header_text or 'anstellungsart' in header_text:
                    details['contractType'] = text_value
                # Caută Domeniul de activitate
                elif 'job function' in header_text or 'tätigkeitsbereich' in header_text:
                    details['workType'] = text_value
                # Caută Industriile
                elif 'industries' in header_text or 'branchen' in header_text:
                    details['sector'] = text_value
    return details


# --- Etapa Unică: Căutare, Extragere și Salvare ---
filters_to_run = get_user_choice()
time_start = time.time()
last_save_time = time_start
total_jobs_processed = 0

for filter_details in filters_to_run:
    time_param = filter_details['seconds']
    time_label = filter_details['label']
    print(f"\n--- 🔍 Încep căutarea pentru perioada: '{time_label}' ---")

    for city in germany_cities:
        for kw in keywords:
            for start in range(0, 250, 25):
                search_url = f'https://www.linkedin.com/jobs/search/?keywords={quote(kw)}&location={quote(city)}&f_TPR={time_param}&start={start}'
                print(f"--- Accesez pagina de căutare: {kw} (pagina {start//25 + 1}) ---")
                
                try:
                    response = requests.get(search_url, headers=headers, timeout=15)
                    response.raise_for_status()
                    soup = BeautifulSoup(response.text, 'html.parser')
                    job_cards = soup.find_all('div', class_='base-card')
                    
                    if not job_cards:
                        break

                    for job in job_cards:
                        link_element = job.find('a', class_='base-card__full-link')
                        clean_link = link_element['href'].split('?')[0] if link_element else ''

                        if clean_link and clean_link not in unique_job_links:
                            unique_job_links.add(clean_link)
                            total_jobs_processed += 1
                            
                            print(f"    -> Procesez jobul {total_jobs_processed}: {clean_link.split('/')[-1]}")

                            try:
                                job_response = requests.get(clean_link, headers=headers, timeout=12)
                                job_response.raise_for_status()
                                job_soup = BeautifulSoup(job_response.text, 'html.parser')
                                
                                title = job.find('h3', class_='base-search-card__title').text.strip()
                                company = job.find('h4', class_='base-search-card__subtitle').text.strip()
                                location = job.find('span', class_='job-search-card__location').text.strip()
                                
                                job_details = extract_job_details(job_soup)

                                jobs_list.append({
                                    'Title': title,
                                    'Company': company,
                                    'Location': location,
                                    'Link': clean_link,
                                    'Keyword': kw,
                                    'City_Searched': city,
                                    'Time_Filter': time_label,
                                    'Published_At': job_details['publishedAt'],
                                    'Contract_Type': job_details['contractType'],
                                    'Experience_Level': job_details['experienceLevel'], # CÂMP NOU
                                    'Work_Type': job_details['workType'],
                                    'Sector': job_details['sector'],
                                    'Salary': job_details['salary'], # CÂMP NOU
                                    'Description': job_details['description']
                                })
                                
                                ### PAUZA 1 ###
                                time.sleep(random.uniform(8, 18))

                            except requests.exceptions.RequestException as e:
                                print(f"      ❌ Eroare la accesarea paginii jobului {clean_link}: {e}")
                    
                    # ### PAUZA 2 ###
                    print(f"--- Pauză după procesarea paginii {start//25 + 1} ---")
                    time.sleep(random.uniform(5, 12))
                                
                    if time.time() - last_save_time > autosave_interval:
                        print(f"\n--- ⏱️ AUTOSAVE: Salvez {len(jobs_list)} joburi în '{output_file}'... ---")
                        save_data_to_json(jobs_list, output_file)
                        last_save_time = time.time()

                except requests.exceptions.RequestException as e:
                    print(f"❌ Eroare la accesarea paginii de căutare {search_url}: {e}")
                    time.sleep(15)

# --- Salvarea finală ---
if jobs_list:
    print(f"\n💾 Salvare finală: Salvez toate cele {len(jobs_list)} rezultate în fișierul '{output_file}'...")
    save_data_to_json(jobs_list, output_file)
    print(f"\n✅ Gata! Datele au fost salvate în fișierul '{output_file}'.")
else:
    print("\n🤷‍♂️ Nu au fost găsite joburi. Scriptul se va încheia.")

time_end = time.time()
total_duration_seconds = time_end - time_start
duration_formatted = str(datetime.timedelta(seconds=total_duration_seconds))
print(f"\n⏱️ Cautarea a durat: {duration_formatted}")
# Out:
# 🤖 Bun venit! Alegeți perioada pentru căutarea de joburi:
# ==================================================
# 1: Ultima lună (o singură căutare)
# 2: Ultimele 3 luni (rulează 3 căutări: pt 1, 2, și 3 luni)
# 3: Ultimele 6 luni (rulează 6 căutări: pt 1, 2...6 luni)
# 4: Perioadă personalizată (ex: ultimele 4 luni)
# 5: Oricând (toate joburile, o singură căutare)
# ==================================================
# Introduceți numărul opțiunii (1-5):  3
# ✅ Ați ales: Căutare secvențială pentru ultimele 6 luni.
#
# --- 🔍 Încep căutarea pentru perioada: 'Ultimele 1 luni' ---
# --- Accesez pagina de căutare: E-Commerce Marketing Specialist (pagina 1) ---
#     -> Procesez jobul 1: e-commerce-marketing-automation-specialist-m-w-d-at-hrrk-recruiting-4304411840
#     -> Procesez jobul 2: digital-marketing-specialist-m-f-d-at-allunity-4305075415
#     -> Procesez jobul 3: trade-marketing-specialist-ecom-digital-shelf-m-w-d-at-brown-forman-4289472676
#     -> Procesez jobul 4: search-specialist-d%C3%BCsseldorf-all-gender-at-digitl-4305075489
#     -> Procesez jobul 5: search-specialist-hamburg-all-genders-at-digitl-4305077460
#     -> Procesez jobul 6: search-specialist-m%C3%BCnchen-all-gender-at-digitl-4311461374
#     -> Procesez jobul 7: ad-technology-consultant-d%C3%BCsseldorf-all-genders-at-digitl-4312443256
#     -> Procesez jobul 8: ad-technology-consultant-hamburg-all-genders-at-digitl-4305827376
#     -> Procesez jobul 9: senior-localisation-specialist-dutch-marketplace-at-booking-com-4296415162
# --- Pauză după procesarea paginii 1 ---
# --- Accesez pagina de căutare: E-Commerce Marketing Specialist (pagina 2) ---
# --- Pauză după procesarea paginii 2 ---
# --- Accesez pagina de căutare: E-Commerce Marketing Specialist (pagina 3) ---
# --- Pauză după procesarea paginii 3 ---
# --- Accesez pagina de căutare: E-Commerce Marketing Specialist (pagina 4) ---
# --- Pauză după procesarea paginii 4 ---
# --- Accesez pagina de căutare: E-Commerce Marketing Specialist (pagina 5) ---
# --- Pauză după procesarea paginii 5 ---
# --- Accesez pagina de căutare: E-Commerce Marketing Specialist (pagina 6) ---
# --- Pauză după procesarea paginii 6 ---
# --- Accesez pagina de căutare: E-Commerce Marketing Specialist (pagina 7) ---
# --- Pauză după procesarea paginii 7 ---
# --- Accesez pagina de căutare: E-Commerce Marketing Specialist (pagina 8) ---
# ❌ Eroare la accesarea paginii de căutare https://www.linkedin.com/jobs/search/?keywords=E-Commerce%20Marketing%20Specialist&location=Germany&f_TPR=r2592000&start=175: 429 Client Error: Request denied for url: https://www.linkedin.com/jobs/search/?keywords=E-Commerce%20Marketing%20Specialist&location=Germany&f_TPR=r2592000&start=175
# --- Accesez pagina de căutare: E-Commerce Marketing Specialist (pagina 9) ---
# --- Pauză după procesarea paginii 9 ---
# --- Accesez pagina de căutare: E-Commerce Marketing Specialist (pagina 10) ---
# --- Pauză după procesarea paginii 10 ---
# --- Accesez pagina de căutare: Online Sales Specialist (pagina 1) ---
#     -> Procesez jobul 10: sales-specialist-at-insidea-4306647885
#     -> Procesez jobul 11: online-shopping-operation-specialist-contractor-at-huawei-4315021775
#     -> Procesez jobul 12: remote-client-relations-marketing-specialist-at-blue-shed-group-4307512336
#     -> Procesez jobul 13: field-account-manager-golf-at-puma-group-4313270758
#     -> Procesez jobul 14: online-sales-consultant-closer-m-w-d-at-bauer-immobilien-unternehmensgruppe-4309985406
#     -> Procesez jobul 15: sales-executive-at-sherpany-4303394409
#       ❌ Eroare la accesarea paginii jobului https://de.linkedin.com/jobs/view/sales-executive-at-sherpany-4303394409: 429 Client Error: Request denied for url: https://de.linkedin.com/jobs/view/sales-executive-at-sherpany-4303394409
#     -> Procesez jobul 16: e-commerce-kaufmann-online-sales-beratung-von-fotografie-equipment-m-w-d-at-foto-hamer-4301444438
#     -> Procesez jobul 17: online-sales-specialist-m-w-d-at-waldhausen-gmbh-co-kg-4316846761
#       ❌ Eroare la accesarea paginii jobului https://de.linkedin.com/jobs/view/online-sales-specialist-m-w-d-at-waldhausen-gmbh-co-kg-4316846761: 429 Client Error: Request denied for url: https://de.linkedin.com/jobs/view/online-sales-specialist-m-w-d-at-waldhausen-gmbh-co-kg-4316846761
#     -> Procesez jobul 18: team-assistant-quick-commerce-at-delivery-hero-4315098965
#     -> Procesez jobul 19: nebenjob-privater-spanischlehrer-m-w-d-online-m%C3%B6glich-at-nachhilfeunterricht-4306642927
#     -> Procesez jobul 20: nebenjob-privater-spanischlehrer-m-w-d-online-m%C3%B6glich-at-nachhilfeunterricht-4306659152
#     -> Procesez jobul 21: client-solutions-manager-comprehensive-retailers-global-business-solutions-berlin-at-tiktok-4312164074
#     -> Procesez jobul 22: nebenjob-privater-spanischlehrer-m-w-d-online-m%C3%B6glich-at-nachhilfeunterricht-4304080216
#     -> Procesez jobul 23: account-marketing-specialist-at-yeti-4309013862
#     -> Procesez jobul 24: team-lead-online-call-center-at-neo-group-4315815663
#     -> Procesez jobul 25: conversion-manager-at-instaffo-4311326296
#     -> Procesez jobul 26: amazon-marketplace-manager-m-w-d-remote-minijob-at-neolymp-4311016420
#     -> Procesez jobul 27: manager-enterprise-sales-product-sales-specialists-at-adobe-4310957122
#     -> Procesez jobul 28: key-account-manager-m-w-d-at-veepee-4309692427
#     -> Procesez jobul 29: influencer-marketing-specialist-at-lancelot-productions-lda-4297843190
#     -> Procesez jobul 30: nebenjob-privater-spanischlehrer-m-w-d-online-m%C3%B6glich-at-nachhilfeunterricht-4305517655
#     -> Procesez jobul 31: nebenjob-privater-spanischlehrer-m-w-d-online-m%C3%B6glich-at-nachhilfeunterricht-4305520488
#     -> Procesez jobul 32: nebenjob-privater-spanischlehrer-m-w-d-online-m%C3%B6glich-at-nachhilfeunterricht-4304087076
#     -> Procesez jobul 33: gtm-associate-m-f-d-at-praxipal-4309637334
#     -> Procesez jobul 34: influencer-relations-manager-m-f-d-at-audiencly-influencer-marketing-agency-4309991539
#     -> Procesez jobul 35: nebenjob-privater-spanischlehrer-m-w-d-online-m%C3%B6glich-at-nachhilfeunterricht-4305508996
#     -> Procesez jobul 36: nebenjob-privater-spanischlehrer-m-w-d-online-m%C3%B6glich-at-nachhilfeunterricht-4306655638
#     -> Procesez jobul 37: nebenjob-privater-spanischlehrer-m-w-d-online-m%C3%B6glich-at-nachhilfeunterricht-4304054298
#     -> Procesez jobul 38: nebenjob-privater-spanischlehrer-m-w-d-online-m%C3%B6glich-at-nachhilfeunterricht-4304058242
#     -> Procesez jobul 39: nebenjob-privater-spanischlehrer-m-w-d-online-m%C3%B6glich-at-nachhilfeunterricht-4305520501
#     -> Procesez jobul 40: nebenjob-privater-spanischlehrer-m-w-d-online-m%C3%B6glich-at-nachhilfeunterricht-4304090082
#     -> Procesez jobul 41: nebenjob-privater-spanischlehrer-m-w-d-online-m%C3%B6glich-at-nachhilfeunterricht-4304061366
#     -> Procesez jobul 42: werk-reis-in-portugal%21-ontvang-2000-bonus-at-sb-joint-academy-4313193954
#     -> Procesez jobul 43: hands-on-vertrieb-marketing-m-w-d-%E2%80%93-junge-weinmarke-auch-teilzeit-od-werkstudent-m%C3%B6glich-at-weinerei-hansen-gmbh-4313344699
#     -> Procesez jobul 44: client-solutions-manager-comprehensive-retailers-global-business-solutions-munich-at-tiktok-4312836140
#     -> Procesez jobul 45: client-solutions-manager-comprehensive-retailers-global-business-solutions-hamburg-at-tiktok-4312828648
#     -> Procesez jobul 46: werk-reis-in-portugal%21-ontvang-2000-bonus-at-sb-joint-academy-4313503633
#     -> Procesez jobul 47: nebenjob-privater-spanischlehrer-m-w-d-online-m%C3%B6glich-at-nachhilfeunterricht-4304091137
#     -> Procesez jobul 48: nebenjob-privater-spanischlehrer-m-w-d-online-m%C3%B6glich-at-nachhilfeunterricht-4304076243
#     -> Procesez jobul 49: nebenjob-privater-spanischlehrer-m-w-d-online-m%C3%B6glich-at-nachhilfeunterricht-4304069036
#     -> Procesez jobul 50: werk-reis-in-portugal%21-ontvang-2000-bonus-at-sb-joint-academy-4313500734
#     -> Procesez jobul 51: marketing-specialist-fully-remote-at-mercor-4303557771
#     -> Procesez jobul 52: go-to-market-partnerships-intern-m-f-d-at-praxipal-4309625661
#     -> Procesez jobul 53: nebenjob-privater-spanischlehrer-m-w-d-online-m%C3%B6glich-at-nachhilfeunterricht-4306643880
#     -> Procesez jobul 54: werk-reis-in-portugal%21-ontvang-2000-bonus-at-sb-joint-academy-4313507484
#     -> Procesez jobul 55: nebenjob-privater-spanischlehrer-m-w-d-online-m%C3%B6glich-at-nachhilfeunterricht-4304068421
#     -> Procesez jobul 56: nebenjob-privater-spanischlehrer-m-w-d-online-m%C3%B6glich-at-nachhilfeunterricht-4305517624
#     -> Procesez jobul 57: werk-reis-in-portugal%21-ontvang-2000-bonus-at-sb-joint-academy-4313503632
#     -> Procesez jobul 58: nebenjob-privater-spanischlehrer-m-w-d-online-m%C3%B6glich-at-nachhilfeunterricht-4304070962
#     -> Procesez jobul 59: au%C3%9Fendienstmitarbeiter-at-mv-impact-gmbh-4302386649
#     -> Procesez jobul 60: werk-reis-in-portugal%21-ontvang-2000-bonus-at-sb-joint-academy-4313505629
#     -> Procesez jobul 61: werk-reis-in-portugal%21-ontvang-2000-bonus-at-sb-joint-academy-4313195943
#     -> Procesez jobul 62: nebenjob-privater-spanischlehrer-m-w-d-online-m%C3%B6glich-at-nachhilfeunterricht-4305532002
#     -> Procesez jobul 63: full-time-assistant-manager-at-cinemark-4309015983
#     -> Procesez jobul 64: assistant-to-sales-managing-director-and-team-m-w-d-at-qplix-gmbh-4293192927
#     -> Procesez jobul 65: i-want-to-be-part-of-the-team%21-at-circunomics-4301858994
#     -> Procesez jobul 66: nebenjob-privater-spanischlehrer-m-w-d-online-m%C3%B6glich-at-nachhilfeunterricht-4304077225
#     -> Procesez jobul 67: office-assistant-at-zebronics-4313113029
#     -> Procesez jobul 68: account-strateg-in-junior-m-w-d-in-google-ads-at-beilmann-marketing-4313323567
#     -> Procesez jobul 69: audi-assistenz-backoffice-ga-m-w-d-at-audi-berlin-gmbh-4305358406
# --- Pauză după procesarea paginii 1 ---
#
# --- ⏱️ AUTOSAVE: Salvez 67 joburi în 'E-Commerce_jobs_germany6month_19_10.json'... ---
# --- Accesez pagina de căutare: Online Sales Specialist (pagina 2) ---
# ❌ Eroare la accesarea paginii de căutare https://www.linkedin.com/jobs/search/?keywords=Online%20Sales%20Specialist&location=Germany&f_TPR=r2592000&start=25: 429 Client Error: Request denied for url: https://www.linkedin.com/jobs/search/?keywords=Online+Sales+Specialist&location=Germany&f_TPR=r2592000&start=0
# --- Accesez pagina de căutare: Online Sales Specialist (pagina 3) ---
# --- Pauză după procesarea paginii 3 ---
# --- Accesez pagina de căutare: Online Sales Specialist (pagina 4) ---
# --- Pauză după procesarea paginii 4 ---
# --- Accesez pagina de căutare: Online Sales Specialist (pagina 5) ---
# --- Pauză după procesarea paginii 5 ---
# --- Accesez pagina de căutare: Online Sales Specialist (pagina 6) ---
# --- Pauză după procesarea paginii 6 ---
# --- Accesez pagina de căutare: Online Sales Specialist (pagina 7) ---
# --- Pauză după procesarea paginii 7 ---
# --- Accesez pagina de căutare: Online Sales Specialist (pagina 8) ---
# --- Pauză după procesarea paginii 8 ---
# --- Accesez pagina de căutare: Online Sales Specialist (pagina 9) ---
# --- Pauză după procesarea paginii 9 ---
# --- Accesez pagina de căutare: Online Sales Specialist (pagina 10) ---
# --- Pauză după procesarea paginii 10 ---
# --- Accesez pagina de căutare: E-Commerce Spezialist (pagina 1) ---
#     -> Procesez jobul 70: e-commerce-at-bbv-domke-gmbh-co-kg-4304791443
#     -> Procesez jobul 71: ecommerce-specialist-at-salt-4308764681
#     -> Procesez jobul 72: e-commerce-assistant-manager-at-xiaomi-technology-4306699857
#     -> Procesez jobul 73: e-commerce-spezialist-in-at-styleranking-media-gmbh-4313994325
#     -> Procesez jobul 74: amazon-e-commerce-office-spezialist-at-fritzi-aus-preu%C3%9Fen-4315820932
#     -> Procesez jobul 75: e-commerce-specialist-m-w-d-at-w%C3%BCsthof-4310874778
#     -> Procesez jobul 76: e-commerce-specialist-all-genders-at-ghd-4312076232
#     -> Procesez jobul 77: e-commerce-specialist-germany-at-alyors-group-4310856346
#     -> Procesez jobul 78: shopmanager-%E2%80%93-e%E2%80%91commerce-marktpl%C3%A4tze-at-instaffo-4298289560
#     -> Procesez jobul 79: mitarbeiter-ecommerce-m-w-d-at-kamberi-group-4307250624
#       ❌ Eroare la accesarea paginii jobului https://de.linkedin.com/jobs/view
duales-studium-bwl-spezialisierung-international-management-b-a-am-campus-oder-virtuell-at-iu-international-university-of-applied-sciences-3921485425
#     -> Procesez jobul 237: duales-studium-bwl-spezialisierung-international-management-b-a-am-campus-oder-virtuell-at-iu-international-university-of-applied-sciences-3921481651
#     -> Procesez jobul 238: duales-studium-bwl-spezialisierung-international-management-b-a-am-campus-oder-virtuell-at-iu-international-university-of-applied-sciences-4007823068
#     -> Procesez jobul 239: duales-studium-bwl-spezialisierung-international-management-b-a-am-campus-oder-virtuell-at-iu-international-university-of-applied-sciences-3921486034
#     -> Procesez jobul 240: duales-studium-bwl-spezialisierung-international-management-b-a-am-campus-oder-virtuell-at-iu-international-university-of-applied-sciences-3921482676
#     -> Procesez jobul 241: duales-studium-bwl-spezialisierung-international-management-b-a-am-campus-oder-virtuell-at-iu-international-university-of-applied-sciences-3921481649
#     -> Procesez jobul 242: duales-studium-bwl-spezialisierung-international-management-b-a-am-campus-oder-virtuell-at-iu-international-university-of-applied-sciences-3921485426
#     -> Procesez jobul 243: duales-studium-bwl-spezialisierung-international-management-b-a-am-campus-oder-virtuell-at-iu-international-university-of-applied-sciences-3921480735
#     -> Procesez jobul 244: duales-studium-bwl-spezialisierung-international-management-b-a-am-campus-oder-virtuell-at-iu-international-university-of-applied-sciences-3921480743
#     -> Procesez jobul 245: duales-studium-bwl-spezialisierung-international-management-b-a-am-campus-oder-virtuell-at-iu-international-university-of-applied-sciences-3921480738
#     -> Procesez jobul 246: duales-studium-bwl-spezialisierung-international-management-b-a-am-campus-oder-virtuell-at-iu-international-university-of-applied-sciences-3921484623
#       ❌ Eroare la accesarea paginii jobului https://de.linkedin.com/jobs/view/duales-studium-bwl-spezialisierung-international-management-b-a-am-campus-oder-virtuell-at-iu-international-university-of-applied-sciences-3921484623: 429 Client Error: Request denied for url: https://de.linkedin.com/jobs/view/duales-studium-bwl-spezialisierung-international-management-b-a-am-campus-oder-virtuell-at-iu-international-university-of-applied-sciences-3921484623
#     -> Procesez jobul 247: duales-studium-bwl-spezialisierung-international-management-b-a-am-campus-oder-virtuell-at-iu-international-university-of-applied-sciences-3921484622
# --- Pauză după procesarea paginii 1 ---
#
# --- ⏱️ AUTOSAVE: Salvez 236 joburi în 'E-Commerce_jobs_germany6month_19_10.json'... ---
# --- Accesez pagina de căutare: Amazon Marketplace Manager  (pagina 2) ---
# ❌ Eroare la accesarea paginii de căutare https://www.linkedin.com/jobs/search/?keywords=Amazon%20Marketplace%20Manager%20&location=Germany&f_TPR=r2592000&start=25: 429 Client Error: Request denied for url: https://www.linkedin.com/jobs/search/?keywords=Amazon%20Marketplace%20Manager%20&location=Germany&f_TPR=r2592000&start=25
# --- Accesez pagina de căutare: Amazon Marketplace Manager  (pagina 3) ---
# --- Pauză după procesarea paginii 3 ---
# --- Accesez pagina de căutare: Amazon Marketplace Manager  (pagina 4) ---
# --- Pauză după procesarea paginii 4 ---
# --- Accesez pagina de căutare: Amazon Marketplace Manager  (pagina 5) ---
# --- Pauză după procesarea paginii 5 ---
# --- Accesez pagina de căutare: Amazon Marketplace Manager  (pagina 6) ---
# ❌ Eroare la accesarea paginii de căutare https://www.linkedin.com/jobs/search/?keywords=Amazon%20Marketplace%20Manager%20&location=Germany&f_TPR=r2592000&start=125: 429 Client Error: Request denied for url: https://www.linkedin.com/jobs/search/?keywords=Amazon+Marketplace+Manager+&location=Germany&f_TPR=r2592000&start=0
# --- Accesez pagina de căutare: Amazon Marketplace Manager  (pagina 7) ---
# --- Pauză după procesarea paginii 7 ---
# --- Accesez pagina de căutare: Amazon Marketplace Manager  (pagina 8) ---
# --- Pauză după procesarea paginii 8 ---
# --- Accesez pagina de căutare: Amazon Marketplace Manager  (pagina 9) ---
# --- Pauză după procesarea paginii 9 ---
# --- Accesez pagina de căutare: Amazon Marketplace Manager  (pagina 10) ---
# --- Pauză după procesarea paginii 10 ---
# --- Accesez pagina de căutare: E-Commerce Specialist (pagina 1) ---
#     -> Procesez jobul 248: teamlead-marktplatz-e-commerce-m-w-d-at-eterna-mode-gmbh-4315649014
#     -> Procesez jobul 249: team-lead-amazon-e-commerce-marketplaces-at-kijimea-synformulas-gmbh-4305345421
#     -> Procesez jobul 250: supply-chain-associate-ecommerce-at-newell-brands-4312993558
#     -> Procesez jobul 251: ecommerce-trading-executive-private-label-at-edgewell-personal-care-4300867978
#     -> Procesez jobul 252: key-account-manager-m-w-d-international-e-commerce-at-kessel-drainage-technology-4315312050
#     -> Procesez jobul 253: specialist-at-kotra-hamburg-4316344768
#     -> Procesez jobul 254: e-commerce-kaufmann-bei-weinhandel-vinello-m-w-d-dresden-vollzeit-at-vinello-retail-gmbh-4307524899
#       ❌ Eroare la accesarea paginii jobului https://de.linkedin.com/jobs/view/e-commerce-kaufmann-bei-weinhandel-vinello-m-w-d-dresden-vollzeit-at-vinello-retail-gmbh-4307524899: 429 Client Error: Request denied for url: https://de.linkedin.com/jobs/view/e-commerce-kaufmann-bei-weinhandel-vinello-m-w-d-dresden-vollzeit-at-vinello-retail-gmbh-4307524899
#     -> Procesez jobul 255: junior-graphic-designer-for-packaging-listing-images-detail-obsessed-amazon-ecommerce-focus-long-term-freelance-at-skyve-4314343119
#     -> Procesez jobul 256: internship-global-ecommerce-content-at-henkel-4306230039
#     -> Procesez jobul 257: marketing-und-vertrieb-at-g%C3%BCnther-pulverich-gmbh-4308174516
#     -> Procesez jobul 258: import-specialist-at-sf-express-europe-4304058088
#       ❌ Eroare la accesarea paginii jobului https://de.linkedin.com/jobs/view/import-specialist-at-sf-express-europe-4304058088: 429 Client Error: Request denied for url: https://de.linkedin.com/jobs/view/import-specialist-at-sf-express-europe-4304058088
#     -> Procesez jobul 259: ecommerce-%2B-online-shop-manager-at-technocycle-gmbh-4315840214
#     -> Procesez jobul 260: junior-sales-e-commerce-category-manager-m-w-d-at-lindt-spr%C3%BCngli-deutschland-4313031821
#     -> Procesez jobul 261: 100%25-remote-front-end-developer-a-b-testing-shopify-apps-ecommerce-focus-gn-contractor-position-at-accelerated-4301467841
#     -> Procesez jobul 262: internship-marketplace-management-global-ecommerce-m-f-d-at-hugo-boss-4310859657
#     -> Procesez jobul 263: e-commerce-manager-at-instaffo-4298769751
# --- Accesez pagina de căutare: Customer Service Specialist Logistik & E-Commerce (pagina 1) ---
# --- Pauză după procesarea paginii 1 ---
# --- Accesez pagina de căutare: Customer Service Specialist Logistik & E-Commerce (pagina 2) ---
# --- Pauză după procesarea paginii 2 ---
# --- Accesez pagina de căutare: Customer Service Specialist Logistik & E-Commerce (pagina 3) ---
# --- Pauză după procesarea paginii 3 ---
# --- Accesez pagina de căutare: Customer Service Specialist Logistik & E-Commerce (pagina 4) ---
# --- Pauză după procesarea paginii 4 ---
# --- Accesez pagina de căutare: Customer Service Specialist Logistik & E-Commerce (pagina 5) ---
# --- Pauză după procesarea paginii 5 ---
# --- Accesez pagina de căutare: Customer Service Specialist Logistik & E-Commerce (pagina 6) ---
# --- Pauză după procesarea paginii 6 ---
# --- Accesez pagina de căutare: Customer Service Specialist Logistik & E-Commerce (pagina 7) ---
# --- Pauză după procesarea paginii 7 ---
# --- Accesez pagina de căutare: Customer Service Specialist Logistik & E-Commerce (pagina 8) ---
# --- Pauză după procesarea paginii 8 ---
# --- Accesez pagina de căutare: Customer Service Specialist Logistik & E-Commerce (pagina 9) ---
# --- Pauză după procesarea paginii 9 ---
# --- Accesez pagina de căutare: Customer Service Specialist Logistik & E-Commerce (pagina 10) ---
# --- Pauză după procesarea paginii 10 ---
# --- Accesez pagina de căutare: Kaufmännischer Mitarbeiter Schwerpunkt Auftragsbearbeitung (pagina 1) ---
# --- Pauză după procesarea paginii 1 ---
# --- Accesez pagina de căutare: Kaufmännischer Mitarbeiter Schwerpunkt Auftragsbearbeitung (pagina 2) ---
# --- Pauză după procesarea paginii 2 ---
# --- Accesez pagina de căutare: Kaufmännischer Mitarbeiter Schwerpunkt Auftragsbearbeitung (pagina 3) ---
# --- Pauză după procesarea paginii 3 ---
# --- Accesez pagina de căutare: Kaufmännischer Mitarbeiter Schwerpunkt Auftragsbearbeitung (pagina 4) ---
# --- Pauză după procesarea paginii 4 ---
# --- Accesez pagina de căutare: Kaufmännischer Mitarbeiter Schwerpunkt Auftragsbearbeitung (pagina 5) ---
# --- Pauză după procesarea paginii 5 ---
# --- Accesez pagina de căutare: Kaufmännischer Mitarbeiter Schwerpunkt Auftragsbearbeitung (pagina 6) ---
# --- Pauză după procesarea paginii 6 ---
# --- Accesez pagina de căutare: Kaufmännischer Mitarbeiter Schwerpunkt Auftragsbearbeitung (pagina 7) ---
# --- Pauză după procesarea paginii 7 ---
# --- Accesez pagina de căutare: Kaufmännischer Mitarbeiter Schwerpunkt Auftragsbearbeitung (pagina 8) ---
# --- Pauză după procesarea paginii 8 ---
# --- Accesez pagina de căutare: Kaufmännischer Mitarbeiter Schwerpunkt Auftragsbearbeitung (pagina 9) ---
# --- Pauză după procesarea paginii 9 ---
# --- Accesez pagina de căutare: Kaufmännischer Mitarbeiter Schwerpunkt Auftragsbearbeitung (pagina 10) ---
# --- Pauză după procesarea paginii 10 ---
# --- Accesez pagina de căutare: Customer Service Mitarbeiter in E-Commerce (pagina 1) ---
# --- Pauză după procesarea paginii 1 ---
# --- Accesez pagina de căutare: Customer Service Mitarbeiter in E-Commerce (pagina 2) ---
# --- Pauză după procesarea paginii 2 ---
# --- Accesez pagina de căutare: Customer Service Mitarbeiter in E-Commerce (pagina 3) ---
# --- Pauză după procesarea paginii 3 ---
# --- Accesez pagina de căutare: Customer Service Mitarbeiter in E-Commerce (pagina 4) ---
# --- Pauză după procesarea paginii 4 ---
# --- Accesez pagina de căutare: Customer Service Mitarbeiter in E-Commerce (pagina 5) ---
# ❌ Eroare la accesarea paginii de căutare https://www.linkedin.com/jobs/search/?keywords=Customer%20Service%20Mitarbeiter%20in%20E-Commerce&location=Germany&f_TPR=r15552000&start=100: 429 Client Error: Request denied for url: https://www.linkedin.com/jobs/search/?keywords=Customer%20Service%20Mitarbeiter%20in%20E-Commerce&location=Germany&f_TPR=r15552000&start=100
# --- Accesez pagina de căutare: Customer Service Mitarbeiter in E-Commerce (pagina 6) ---
# --- Pauză după procesarea paginii 6 ---
#
# --- ⏱️ AUTOSAVE: Salvez 692 joburi în 'E-Commerce_jobs_germany6month_19_10.json'... ---
# --- Accesez pagina de căutare: Customer Service Mitarbeiter in E-Commerce (pagina 7) ---
# --- Pauză după procesarea paginii 7 ---
# --- Accesez pagina de căutare: Customer Service Mitarbeiter in E-Commerce (pagina 8) ---
# --- Pauză după procesarea paginii 8 ---
# --- Accesez pagina de căutare: Customer Service Mitarbeiter in E-Commerce (pagina 9) ---
# --- Pauză după procesarea paginii 9 ---
# --- Accesez pagina de căutare: Customer Service Mitarbeiter in E-Commerce (pagina 10) ---
# --- Pauză după procesarea paginii 10 ---
# --- Accesez pagina de căutare: Werkstudent/in Customer Care E-Commerce (pagina 1) ---
# --- Pauză după procesarea paginii 1 ---
# --- Accesez pagina de căutare: Werkstudent/in Customer Care E-Commerce (pagina 2) ---
# --- Pauză după procesarea paginii 2 ---
# --- Accesez pagina de căutare: Werkstudent/in Customer Care E-Commerce (pagina 3) ---
# ❌ Eroare la accesarea paginii de căutare https://www.linkedin.com/jobs/search/?keywords=Werkstudent/in%20Customer%20Care%20E-Commerce&location=Germany&f_TPR=r15552000&start=50: 429 Client Error: Request denied for url: https://www.linkedin.com/jobs/search/?keywords=Werkstudent%2Fin+Customer+Care+E-Commerce&location=Germany&f_TPR=r15552000&start=0
# --- Accesez pagina de căutare: Werkstudent/in Customer Care E-Commerce (pagina 4) ---
# --- Pauză după procesarea paginii 4 ---
# --- Accesez pagina de căutare: Werkstudent/in Customer Care E-Commerce (pagina 5) ---
# ❌ Eroare la accesarea paginii de căutare https://www.linkedin.com/jobs/search/?keywords=Werkstudent/in%20Customer%20Care%20E-Commerce&location=Germany&f_TPR=r15552000&start=100: 429 Client Error: Request denied for url: https://www.linkedin.com/jobs/search/?keywords=Werkstudent%2Fin+Customer+Care+E-Commerce&location=Germany&f_TPR=r15552000&start=0
# --- Accesez pagina de căutare: Werkstudent/in Customer Care E-Commerce (pagina 6) ---
# --- Pauză după procesarea paginii 6 ---
# --- Accesez pagina de căutare: Werkstudent/in Customer Care E-Commerce (pagina 7) ---
# --- Pauză după procesarea paginii 7 ---
# --- Accesez pagina de căutare: Werkstudent/in Customer Care E-Commerce (pagina 8) ---
# --- Pauză după procesarea paginii 8 ---
# --- Accesez pagina de căutare: Werkstudent/in Customer Care E-Commerce (pagina 9) ---
# --- Pauză după procesarea paginii 9 ---
# --- Accesez pagina de căutare: Werkstudent/in Customer Care E-Commerce (pagina 10) ---
# --- Pauză după procesarea paginii 10 ---
# --- Accesez pagina de căutare: E-Commerce Support Specialist (pagina 1) ---
# --- Pauză după procesarea paginii 1 ---
# --- Accesez pagina de căutare: E-Commerce Support Specialist (pagina 2) ---
# --- Pauză după procesarea paginii 2 ---
# --- Accesez pagina de căutare: E-Commerce Support Specialist (pagina 3) ---
# --- Pauză după procesarea paginii 3 ---
# --- Accesez pagina de căutare: E-Commerce Support Specialist (pagina 4) ---
# --- Pauză după procesarea paginii 4 ---
# --- Accesez pagina de căutare: E-Commerce Support Specialist (pagina 5) ---
# --- Pauză după procesarea paginii 5 ---
# --- Accesez pagina de căutare: E-Commerce Support Specialist (pagina 6) ---
# ❌ Eroare la accesarea paginii de căutare https://www.linkedin.com/jobs/search/?keywords=E-Commerce%20Support%20Specialist&location=Germany&f_TPR=r15552000&start=125: 429 Client Error: Request denied for url: https://www.linkedin.com/jobs/search/?keywords=E-Commerce+Support+Specialist&location=Germany&f_TPR=r15552000&start=0
# --- Accesez pagina de căutare: E-Commerce Support Specialist (pagina 7) ---
# --- Pauză după procesarea paginii 7 ---
# --- Accesez pagina de căutare: E-Commerce Support Specialist (pagina 8) ---
# --- Pauză după procesarea paginii 8 ---
# --- Accesez pagina de căutare: E-Commerce Support Specialist (pagina 9) ---
# --- Pauză după procesarea paginii 9 ---
# --- Accesez pagina de căutare: E-Commerce Support Specialist (pagina 10) ---
# --- Pauză după procesarea paginii 10 ---
# --- Accesez pagina de căutare: Customer Service Specialist (Logistik & E-Commerce) (pagina 1) ---
# --- Accesez pagina de căutare: Junior E-Commerce Manager (pagina 1) ---
# --- Pauză după procesarea paginii 1 ---
# --- Accesez pagina de căutare: Junior E-Commerce Manager (pagina 2) ---
# --- Pauză după procesarea paginii 2 ---
# --- Accesez pagina de căutare: Junior E-Commerce Manager (pagina 3) ---
# --- Pauză după procesarea paginii 3 ---
# --- Accesez pagina de căutare: Junior E-Commerce Manager (pagina 4) ---
# --- Pauză după procesarea paginii 4 ---
# --- Accesez pagina de căutare: Junior E-Commerce Manager (pagina 5) ---
# --- Pauză după procesarea paginii 5 ---
#
# --- ⏱️ AUTOSAVE: Salvez 692 joburi în 'E-Commerce_jobs_germany6month_19_10.json'... ---
# --- Accesez pagina de căutare: Junior E-Commerce Manager (pagina 6) ---
# --- Pauză după procesarea paginii 6 ---
# --- Accesez pagina de căutare: Junior E-Commerce Manager (pagina 7) ---
# --- Pauză după procesarea paginii 7 ---
# --- Accesez pagina de căutare: Junior E-Commerce Manager (pagina 8) ---
# --- Pauză după procesarea paginii 8 ---
# --- Accesez pagina de căutare: Junior E-Commerce Manager (pagina 9) ---
# --- Pauză după procesarea paginii 9 ---
# --- Accesez pagina de căutare: Junior E-Commerce Manager (pagina 10) ---
# --- Pauză după procesarea paginii 10 ---
# --- Accesez pagina de căutare: Fachkraft Lagerlogistik Fulfillment / E-Commerce (pagina 1) ---
# --- Accesez pagina de căutare: mitarbeiter/in e-commerce / e-commerce medewerker (pagina 1) ---
# --- Accesez pagina de căutare: e-commerce manager / online shop manager (pagina 1) ---
# --- Pauză după procesarea paginii 1 ---
# --- Accesez pagina de căutare: e-commerce manager / online shop manager (pagina 2) ---
# --- Pauză după procesarea paginii 2 ---
# --- Accesez pagina de căutare: e-commerce manager / online shop manager (pagina 3) ---
# --- Pauză după procesarea paginii 3 ---
# --- Accesez pagina de căutare: e-commerce manager / online shop manager (pagina 4) ---
# --- Pauză după procesarea paginii 4 ---
# --- Accesez pagina de căutare: e-commerce manager / online shop manager (pagina 5) ---
# --- Pauză după procesarea paginii 5 ---
# --- Accesez pagina de căutare: e-commerce manager / online shop manager (pagina 6) ---
# --- Pauză după procesarea paginii 6 ---
# --- Accesez pagina de căutare: e-commerce manager / online shop manager (pagina 7) ---
# --- Pauză după procesarea paginii 7 ---
# --- Accesez pagina de căutare: e-commerce manager / online shop manager (pagina 8) ---
# --- Pauză după procesarea paginii 8 ---
# --- Accesez pagina de căutare: e-commerce manager / online shop manager (pagina 9) ---
# --- Pauză după procesarea paginii 9 ---
# --- Accesez pagina de căutare: e-commerce manager / online shop manager (pagina 10) ---
# --- Pauză după procesarea paginii 10 ---
# --- Accesez pagina de căutare: online marketing manager (pagina 1) ---
# --- Pauză după procesarea paginii 1 ---
# --- Accesez pagina de căutare: online marketing manager (pagina 2) ---
# --- Pauză după procesarea paginii 2 ---
# --- Accesez pagina de căutare: online marketing manager (pagina 3) ---
# --- Pauză după procesarea paginii 3 ---
# --- Accesez pagina de căutare: online marketing manager (pagina 4) ---
# --- Pauză după procesarea paginii 4 ---
# --- Accesez pagina de căutare: online marketing manager (pagina 5) ---
# ❌ Eroare la accesarea paginii de căutare https://www.linkedin.com/jobs/search/?keywords=online%20marketing%20manager&location=Germany&f_TPR=r15552000&start=100: 429 Client Error: Request denied for url: https://www.linkedin.com/jobs/search/?keywords=online%20marketing%20manager&location=Germany&f_TPR=r15552000&start=100
# --- Accesez pagina de căutare: online marketing manager (pagina 6) ---
# --- Pauză după procesarea paginii 6 ---
# --- Accesez pagina de căutare: online marketing manager (pagina 7) ---
# --- Pauză după procesarea paginii 7 ---
# --- Accesez pagina de căutare: online marketing manager (pagina 8) ---
# --- Pauză după procesarea paginii 8 ---
# --- Accesez pagina de căutare: online marketing manager (pagina 9) ---
# --- Pauză după procesarea paginii 9 ---
# --- Accesez pagina de căutare: online marketing manager (pagina 10) ---
# --- Pauză după procesarea paginii 10 ---
# --- Accesez pagina de căutare: product data / katalog manager (pagina 1) ---
# --- Pauză după procesarea paginii 1 ---
# --- Accesez pagina de căutare: product data / katalog manager (pagina 2) ---
# --- Pauză după procesarea paginii 2 ---
# --- Accesez pagina de căutare: product data / katalog manager (pagina 3) ---
# --- Pauză după procesarea paginii 3 ---
# --- Accesez pagina de căutare: product data / katalog manager (pagina 4) ---
# --- Pauză după procesarea paginii 4 ---
# --- Accesez pagina de căutare: product data / katalog manager (pagina 5) ---
# --- Pauză după procesarea paginii 5 ---
# --- Accesez pagina de căutare: product data / katalog manager (pagina 6) ---
# --- Pauză după procesarea paginii 6 ---
#
# --- ⏱️ AUTOSAVE: Salvez 692 joburi în 'E-Commerce_jobs_germany6month_19_10.json'... ---
# --- Accesez pagina de căutare: product data / katalog manager (pagina 7) ---
# --- Pauză după procesarea paginii 7 ---
# --- Accesez pagina de căutare: product data / katalog manager (pagina 8) ---
# --- Pauză după procesarea paginii 8 ---
# --- Accesez pagina de căutare: product data / katalog manager (pagina 9) ---
# --- Pauză după procesarea paginii 9 ---
# --- Accesez pagina de căutare: product data / katalog manager (pagina 10) ---
# --- Pauză după procesarea paginii 10 ---
# --- Accesez pagina de căutare: webshop/shop content manager (pagina 1) ---
# --- Accesez pagina de căutare: Sachbearbeiter E Commerce (pagina 1) ---
# --- Pauză după procesarea paginii 1 ---
# --- Accesez pagina de căutare: Sachbearbeiter E Commerce (pagina 2) ---
# --- Pauză după procesarea paginii 2 ---
# --- Accesez pagina de căutare: Sachbearbeiter E Commerce (pagina 3) ---
# --- Pauză după procesarea paginii 3 ---
# --- Accesez pagina de căutare: Sachbearbeiter E Commerce (pagina 4) ---
# --- Pauză după procesarea paginii 4 ---
# --- Accesez pagina de căutare: Sachbearbeiter E Commerce (pagina 5) ---
# --- Pauză după procesarea paginii 5 ---
# --- Accesez pagina de căutare: Sachbearbeiter E Commerce (pagina 6) ---
# --- Pauză după procesarea paginii 6 ---
# --- Accesez pagina de căutare: Sachbearbeiter E Commerce (pagina 7) ---
# --- Pauză după procesarea paginii 7 ---
# --- Accesez pagina de căutare: Sachbearbeiter E Commerce (pagina 8) ---
# --- Pauză după procesarea paginii 8 ---
# --- Accesez pagina de căutare: Sachbearbeiter E Commerce (pagina 9) ---
# --- Pauză după procesarea paginii 9 ---
# --- Accesez pagina de căutare: Sachbearbeiter E Commerce (pagina 10) ---
# --- Pauză după procesarea paginii 10 ---
# --- Accesez pagina de căutare: Digital Sales Spezialist / Online Sales Spezialist (pagina 1) ---
# --- Accesez pagina de căutare: E-Commerce Marketing Spezialist (pagina 1) ---
# --- Pauză după procesarea paginii 1 ---
# --- Accesez pagina de căutare: E-Commerce Marketing Spezialist (pagina 2) ---
# --- Pauză după procesarea paginii 2 ---
# --- Accesez pagina de căutare: E-Commerce Marketing Spezialist (pagina 3) ---
# --- Pauză după procesarea paginii 3 ---
# --- Accesez pagina de căutare: E-Commerce Marketing Spezialist (pagina 4) ---
# --- Pauză după procesarea paginii 4 ---
# --- Accesez pagina de căutare: E-Commerce Marketing Spezialist (pagina 5) ---
# --- Pauză după procesarea paginii 5 ---
# --- Accesez pagina de căutare: E-Commerce Marketing Spezialist (pagina 6) ---
# --- Pauză după procesarea paginii 6 ---
# --- Accesez pagina de căutare: E-Commerce Marketing Spezialist (pagina 7) ---
# --- Pauză după procesarea paginii 7 ---
# --- Accesez pagina de căutare: E-Commerce Marketing Spezialist (pagina 8) ---
# --- Pauză după procesarea paginii 8 ---
# --- Accesez pagina de căutare: E-Commerce Marketing Spezialist (pagina 9) ---
# --- Pauză după procesarea paginii 9 ---
# --- Accesez pagina de căutare: E-Commerce Marketing Spezialist (pagina 10) ---
# --- Pauză după procesarea paginii 10 ---
#
# 💾 Salvare finală: Salvez toate cele 692 rezultate în fișierul 'E-Commerce_jobs_germany6month_19_10.json'...
#
# ✅ Gata! Datele au fost salvate în fișierul 'E-Commerce_jobs_germany6month_19_10.json'.
#
# ⏱️ Cautarea a durat: 5:49:35.693349
